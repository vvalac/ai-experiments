# %%
! pip install -U langchain-nomic langchain_community tiktoken langchainhub chromadb langchain langgraph tavily-python langchain-openai
# this notebook uses OpenAI for embeddings and LLM inferencing with GPT-4o
# by default, web search is turned off to save API calls when testing/evaluating
# Out:
# Requirement already satisfied: langchain-nomic in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (0.0.2)
# Requirement already satisfied: langchain_community in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (0.0.36)
# Collecting langchain_community
#   Using cached langchain_community-0.0.38-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: tiktoken in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (0.6.0)
# Collecting tiktoken
#   Downloading tiktoken-0.7.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: langchainhub in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (0.1.15)
# Requirement already satisfied: chromadb in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (0.5.0)
# Requirement already satisfied: langchain in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (0.1.17)
# Collecting langchain
#   Using cached langchain-0.1.20-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: langgraph in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (0.0.44)
# Collecting langgraph
#   Downloading langgraph-0.0.48-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tavily-python in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (0.3.3)
# Requirement already satisfied: gpt4all in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (2.6.0)
# Requirement already satisfied: langchain-core<0.2,>=0.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from langchain-nomic) (0.1.50)
# Requirement already satisfied: nomic<4.0.0,>=3.0.12 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from langchain-nomic) (3.0.27)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from langchain_community) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from langchain_community) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from langchain_community) (0.6.4)
# Collecting langchain-core<0.2,>=0.1 (from langchain-nomic)
#   Using cached langchain_core-0.1.52-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from langchain_community) (0.1.47)
# Requirement already satisfied: numpy<2,>=1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from langchain_community) (1.26.3)
# Requirement already satisfied: requests<3,>=2 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from langchain_community) (8.2.3)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from tiktoken) (2023.12.25)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from langchainhub) (2.31.0.20240406)
# Requirement already satisfied: build>=1.0.3 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (1.0.3)
# Requirement already satisfied: pydantic>=1.9 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (2.7.0)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (0.103.0)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.20.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (3.4.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (4.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (1.15.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (0.15.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (1.62.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (4.1.2)
# Requirement already satisfied: typer>=0.9.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (29.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from chromadb) (3.9.15)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from langchain) (0.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: packaging>=19.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: colorama in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.29.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.1.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from langchain-core<0.2,>=0.1->langchain-nomic) (1.33)
# Requirement already satisfied: click in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (8.1.7)
# Requirement already satisfied: jsonlines in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (4.0.0)
# Requirement already satisfied: loguru in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (0.7.2)
# Requirement already satisfied: rich in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (13.7.0)
# Requirement already satisfied: pandas in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (2.1.4)
# Requirement already satisfied: pyarrow in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (15.0.2)
# Requirement already satisfied: pillow in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (10.2.0)
# Requirement already satisfied: pyjwt in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from nomic<4.0.0,>=3.0.12->langchain-nomic) (2.8.0)
# Requirement already satisfied: coloredlogs in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (2.0)
# Requirement already satisfied: protobuf in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Requirement already satisfied: sympy in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (68.0.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from posthog>=2.4.0->chromadb) (1.5)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from posthog>=2.4.0->chromadb) (1.11.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from pydantic>=1.9->chromadb) (2.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from requests<3,>=2->langchain_community) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from requests<3,>=2->langchain_community) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.20.3)
# Requirement already satisfied: h11>=0.8 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.10.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2,>=0.1->langchain-nomic) (2.4)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from starlette<0.28.0,>=0.27.0->fastapi>=0.95.2->chromadb) (4.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from loguru->nomic<4.0.0,>=3.0.12->langchain-nomic) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from pandas->nomic<4.0.0,>=3.0.12->langchain-nomic) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from pandas->nomic<4.0.0,>=3.0.12->langchain-nomic) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from rich->nomic<4.0.0,>=3.0.12->langchain-nomic) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from rich->nomic<4.0.0,>=3.0.12->langchain-nomic) (2.17.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from markdown-it-py>=2.2.0->rich->nomic<4.0.0,>=3.0.12->langchain-nomic) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\adams\anaconda3\envs\saas-dev\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)
# Using cached langchain_community-0.0.38-py3-none-any.whl (2.0 MB)
# Downloading tiktoken-0.7.0-cp311-cp311-win_amd64.whl (799 kB)
#    ---------------------------------------- 0.0/799.0 kB ? eta -:--:--
#     --------------------------------------- 10.2/799.0 kB ? eta -:--:--
#     --------------------------------------- 10.2/799.0 kB ? eta -:--:--
#    --- ----------------------------------- 71.7/799.0 kB 787.7 kB/s eta 0:00:01
#    ------- -------------------------------- 143.4/799.0 kB 1.1 MB/s eta 0:00:01
#    ------------- -------------------------- 266.2/799.0 kB 1.5 MB/s eta 0:00:01
#    ------------------- -------------------- 389.1/799.0 kB 1.6 MB/s eta 0:00:01
#    ------------------- -------------------- 399.4/799.0 kB 1.7 MB/s eta 0:00:01
#    ------------------------------- -------- 634.9/799.0 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  798.7/799.0 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 799.0/799.0 kB 2.1 MB/s eta 0:00:00
# Using cached langchain-0.1.20-py3-none-any.whl (1.0 MB)
# Downloading langgraph-0.0.48-py3-none-any.whl (69 kB)
#    ---------------------------------------- 0.0/70.0 kB ? eta -:--:--
#    ---------------------------------------- 70.0/70.0 kB 3.7 MB/s eta 0:00:00
# Using cached langchain_core-0.1.52-py3-none-any.whl (302 kB)
# Installing collected packages: tiktoken, langchain-core, langgraph, langchain_community, langchain
#   Attempting uninstall: tiktoken
#     Found existing installation: tiktoken 0.6.0
#     Uninstalling tiktoken-0.6.0:
#       Successfully uninstalled tiktoken-0.6.0
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.1.50
#     Uninstalling langchain-core-0.1.50:
#       Successfully uninstalled langchain-core-0.1.50
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 0.0.44
#     Uninstalling langgraph-0.0.44:
#       Successfully uninstalled langgraph-0.0.44
#   Attempting uninstall: langchain_community
#     Found existing installation: langchain-community 0.0.36
#     Uninstalling langchain-community-0.0.36:
#       Successfully uninstalled langchain-community-0.0.36
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.1.17
#     Uninstalling langchain-0.1.17:
#       Successfully uninstalled langchain-0.1.17
# Successfully installed langchain-0.1.20 langchain-core-0.1.52 langchain_community-0.0.38 langgraph-0.0.48 tiktoken-0.7.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\adams\anaconda3\envs\saas-dev\Lib\site-packages\~iktoken'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# crewai-tools 0.1.7 requires chromadb<0.5.0,>=0.4.22, but you have chromadb 0.5.0 which is incompatible.
# embedchain 0.1.100 requires chromadb<0.5.0,>=0.4.17, but you have chromadb 0.5.0 which is incompatible.
# embedchain 0.1.100 requires tiktoken<0.6.0,>=0.5.2, but you have tiktoken 0.7.0 which is incompatible.
# langchain-chroma 0.1.0 requires chromadb<0.5.0,>=0.4.0, but you have chromadb 0.5.0 which is incompatible.
# langchain-openai 0.0.5 requires tiktoken<0.6.0,>=0.5.2, but you have tiktoken 0.7.0 which is incompatible.

# %%
import dotenv
import os

dotenv.load_dotenv()

TAVILY_API_KEY = os.getenv('TAVILY_API_KEY')
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
USE_WEB_SEARCH = 0

# %%
llm = "gpt-4o"

# %%
from langchain_openai import OpenAI, OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter
import json
from langchain_core.documents import Document

jsonl_file_path = "document_data\\ac2_all_documents.jsonl"

dataset = []

embedding = OpenAIEmbeddings(
    model="text-embedding-3-small"
)

# %%
#load dataset as doc list
with open(jsonl_file_path, "r") as file:
    for line in file:
        data = json.loads(line)
        document = Document(**data)
        dataset.append(document)

print(f'Dataset loaded with {len(dataset)} documents.')
# Out:
# Dataset loaded with 499 documents.

# %%
#load vectordb
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=500, chunk_overlap=50
)
doc_splits = text_splitter.split_documents(dataset)

vectorstore = Chroma.from_documents(
    documents=doc_splits,
    collection_name="rag-chroma",
    embedding=embedding,
)
retriever = vectorstore.as_retriever()

# %%
#vectorstore.delete_collection("rag-chroma")

# %%
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import JsonOutputParser

llm = ChatOpenAI(model="gpt-4o", temperature=0)

prompt = PromptTemplate(
    template="""You are a grader assessing relevance 
    of a retrieved document to a user question. If the document contains keywords related to the user question, 
    grade it as relevant. It does not need to be a stringent test. The goal is to filter out erroneous retrievals. \n
    Give a binary score 'yes' or 'no' to indicate whether the document is relevant to the question. \n
    Provide the binary score as a JSON with a single key 'score' and no premable or explaination.
    Here is the retrieved document: \n\n {document} \n\n
    Here is the user question: {question} \n <|eot_id|><|start_header_id|>assistant<|end_header_id|>
    """,
    input_variables=["question", "document"],
)

retrieval_grader = prompt | llm | JsonOutputParser()
question = "arwic"
docs = retriever.invoke(question)
doc_txt = docs[1].page_content
print(retrieval_grader.invoke({"question": question, "document": doc_txt}))
# Out:
# {'score': 'yes'}

# %%
from langchain.prompts import PromptTemplate
from langchain import hub
from langchain_core.output_parsers import StrOutputParser

# Prompt
prompt = PromptTemplate(
    template="""You are a chatbot assistant for question-answering tasks.
    Use the following pieces of retrieved context to answer the question, and respond in a conversational and helpful tone. If 
    you don't know the answer, just say that you don't know. Do not tell the user about documents, provided text, or context information, 
    that information is provided to you by a separate system which was searched based on the user question.
    Be accurate, do not combine context information unless they are directly related (ex. from the same source).
    Context: {context} 
    Question: {question}
    Answer: """,
    input_variables=["question", "context"],
)


# Post-processing
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


# Chain
rag_chain = prompt | llm | StrOutputParser()

# Run
question = "around what level should i head to omishan?"
docs = retriever.invoke(question)
generation = rag_chain.invoke({"context": docs, "question": question})
print(generation)
# Out:
# You should head to Omishan around level 30. Many quests in Omishan, such as the Shreth-Hunter's Guide to Omishan and the Omishan Soulbound Weapon, have a level requirement of 30.

# %%
#hallucination grader
prompt = PromptTemplate(
    template="""You are a grader assessing whether 
    an answer is grounded in / supported by a set of facts. Give a binary 'yes' or 'no' score to indicate 
    whether the answer is grounded in / supported by a set of facts. Provide the binary score as a JSON with a 
    single key 'score' and no preamble or explanation.
    Here are the facts:
    \n ------- \n
    {documents} 
    \n ------- \n
    Here is the answer you need to score as a 'yes' or 'no', attached to the json key 'score': {generation}""",
    input_variables=["generation", "documents"],
)

hallucination_grader = prompt | llm | JsonOutputParser()
graded = hallucination_grader.invoke({"documents": docs, "generation": generation})
print(graded)
# Out:
# {'score': 'yes'}

# %%
#answer grader
prompt = PromptTemplate(
    template="""You are a grader assessing whether an 
    answer is useful to resolve a question. Give a binary score 'yes' or 'no' to indicate whether the answer is 
    useful to resolve a question. Provide the binary score as a JSON with a single key 'score' and no preamble or explanation.
    Here is the answer:
    \n ------- \n
    {generation} 
    \n ------- \n
    Here is the question: {question}""",
    input_variables=["generation", "question"],
)

answer_grader = prompt | llm | JsonOutputParser()
answer_grader.invoke({"question": question, "generation": generation})
# Out:
# {'score': 'yes'}

# %%
# LLM
prompt = PromptTemplate(
    template="""<|begin_of_text|><|start_header_id|>system<|end_header_id|> You are an expert at routing a 
    user question to a vectorstore or web search. Use the vectorstore for questions on the Asheron's Call 2
    MMORPG or any associated topics (quests, monsters, etc...). You do not need to be stringent with the keywords 
    in the question related to these topics. Otherwise, use web-search. Give a binary choice 'web_search' 
    or 'vectorstore' based on the question. Return the a JSON with a single key 'datasource' and 
    no premable or explaination. Question to route: {question} <|eot_id|><|start_header_id|>assistant<|end_header_id|>""",
    input_variables=["question"],
)

question_router = prompt | llm | JsonOutputParser()
# this should return web_search
question = "samsung"
docs = retriever.invoke(question)
doc_txt = docs[1].page_content
print("The result for an unrelated query is " + str(question_router.invoke({"question": question})))
# this should return vectorstore
question = "arwic"
docs = retriever.invoke(question)
doc_txt = docs[1].page_content
print("The result for a related query is " + str(question_router.invoke({"question": question})))
# Out:
# The result for an unrelated query is {'datasource': 'web_search'}
# The result for a related query is {'datasource': 'vectorstore'}

# %%
# setup search
from langchain_community.tools.tavily_search import TavilySearchResults

web_search_tool = TavilySearchResults(k=3)

# %%
from typing_extensions import TypedDict
from typing import List

class GraphState(TypedDict):
    question: str
    generation: str
    web_search: str
    documents: List[str]

# %%
from langchain.schema import Document

def retrieve(state):
    print("---RETRIEVE---")
    question = state["question"]

    documents = retriever.invoke(question)
    return {"documents": documents, "question": question}

def generate(state):
    print("---GENERATE---")
    question = state["question"]
    documents = state["documents"]

    generation = rag_chain.invoke({"context": documents, "question": question})
    return {"documents": documents, "question": question, "generation": generation}

def grade_documents(state):
    print("---GRADE DOCUMENTS---")
    question = state["question"]
    documents = state["documents"]

    filtered_docs = []
    web_search = "no"
    for d in documents:
        score = retrieval_grader.invoke(
            {"question": question, "document": d.page_content}
        )
        grade = score["score"]
        if grade.lower() == "yes":
            print("---GRADE: RELEVANT---")
            filtered_docs.append(d)
        else:
            print("---GRADE: NOT RELEVANT---")
        
    if USE_WEB_SEARCH == 1 and not filtered_docs:
        web_search = "yes"

    return {"documents": filtered_docs, "question": question, "web_search": web_search}

def web_search(state):
    print("---WEB SEARCH---")
    question = state["question"]
    documents = state["documents"]
    
    docs = web_search_tool.invoke({"query": question})
    web_results = "\n".join([d["content"] for d in docs])
    web_results = Document(page_content=web_results)
    if documents is not None:
        documents.append(web_results)
    else:
        documents= [web_results]
    return {"documents": documents, "question": question}

def route_question(state):
    print("---ROUTE QUESTION---")
    question = state["question"]
    print(question)
    source = question_router.invoke({"question": question})
    print(source)
    print(source["datasource"])
    if source["datasource"] == "web_search":
        print("---ROUTE QUESTION TO WEB SEARCH---")
        return "websearch"
    elif source["datasource"] == "vectorstore":
        print("---ROUTE QUESTION TO RAG---")
        return "vectorstore"
    
def decide_to_generate(state):
    print("---ASSESS GRADED DOCUMENTS---")
    question = state["question"]
    web_search = state["web_search"]
    filtered_documents = state["documents"]

    if web_search == "yes" and USE_WEB_SEARCH == 1:
        print("---DECISION: NO RELEVANT DOCS, USE WEB SEARCH---")
        return "websearch"
    else:
        print("---DECISION: GENERATE---")
        return "generate"

def grade_generation_v_documents_and_question(state):
    print("---CHECK HALLUCINATIONS---")
    question = state["question"]
    documents = state["documents"]
    generation = state["generation"]

    score = hallucination_grader.invoke(
        {"documents": documents, "generation": generation}
    )
    grade = score["score"]

    if grade == "yes":
        print("---DECISION: ANSWER GROUNDED IN DOCS---")
        print("---GRADE ANSWER vs QUESTION---")
        score = answer_grader.invoke({"question": question, "generation": generation})
        grade = score["score"]
        if grade == "yes":
            print("---DECISION: ANSWERS QUESTION---")
            return "useful"
        else:
            print("---DECISION: ANSWER DOES NOT ADDRESS QUESSTION---")
            return "not useful"
    else:
        print("---DECISION: GENERATION NOT GROUNDED IN DOCS---")
        return "not supported"

# %%
from langgraph.graph import END, StateGraph

workflow = StateGraph(GraphState)

workflow.add_node("websearch", web_search)
workflow.add_node("retrieve", retrieve)
workflow.add_node("grade_documents", grade_documents)
workflow.add_node("generate", generate)

workflow.set_conditional_entry_point(
    route_question,
    {
        "vectorstore": "retrieve",
        "websearch": "websearch",
    },
)

workflow.add_edge("retrieve", "grade_documents")
workflow.add_conditional_edges(
    "grade_documents",
    decide_to_generate,
    {
        "websearch": "websearch",
        "generate": "generate",
    },
)
workflow.add_edge("websearch", "generate")
workflow.add_conditional_edges(
    "generate",
    grade_generation_v_documents_and_question,
    {
        "not supported": "generate",
        "useful": END,
        "not useful": "websearch",
    },
)

# %%
app = workflow.compile()

from pprint import pprint

question = "what do i need to do to get the arwic mines quest?"

inputs = {"question": question}

for output in app.stream(inputs):
    for key, value in output.items():
        pprint(f"Finished running: {key}:")

pprint(value["generation"])
# Out:
# ---ROUTE QUESTION---
# what do i need to do to get the arwic mines quest?
# {'datasource': 'vectorstore'}
# vectorstore
# ---ROUTE QUESTION TO RAG---
# ---RETRIEVE---
# 'Finished running: retrieve:'
# ---GRADE DOCUMENTS---
# ---GRADE: RELEVANT---
# ---GRADE: RELEVANT---
# ---GRADE: NOT RELEVANT---
# ---GRADE: NOT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# 'Finished running: grade_documents:'
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: ANSWER GROUNDED IN DOCS---
# ---GRADE ANSWER vs QUESTION---
# ---DECISION: ANSWERS QUESTION---
# 'Finished running: generate:'
# ('To get the Arwic Mines Quest, you need to first complete the "Find the Arwic '
#  'Mines Overseer" quest. Here’s a step-by-step guide:\n'
#  '\n'
#  '1. **Complete the Obelisk Search Quests**: You need to finish one of the '
#  'three Obelisk Search Quests.\n'
#  '2. **Talk to the Explorer**: After completing one of the Obelisk Search '
#  'Quests, talk to the zone named Explorer.\n'
#  '3. **Find the Arwic Mines Overseer**: The Explorer will direct you to find '
#  'the Arwic Mines Overseer, who is located in Arwic at coordinates (43.9N, '
#  '6.5W). Use the portal system to get to his location.\n'
#  '4. **Speak to the Arwic Mines Overseer**: Once you find him, speak to him to '
#  'start the Arwic Mines and Crafting Quest.\n'
#  '\n'
#  'After completing these steps, you will be able to start the Arwic Mines and '
#  'Crafting Quest.')
